# %%
class sinh_vien:
    def __init__(self,name,ma_sinh_vien):
        self.name=name
        self.ma_sinh_vien=ma_sinh_vien
    def ngay_sinh(self,dd,mm,yy):
        self.dd=dd
        self.mm=mm
        self.yy=yy
    def diem_trung_binh(self,list_point):
        sum=0
        for i in list_point:
            sum+=i
        return round(sum/(len(list_point)))
    def __repr__(self):
        return self.name +' '+ str(self.ma_sinh_vien)
    
sv=sinh_vien("Bui Quang Chung",25021670)
dtb=sv.diem_trung_binh([8,10])
print(sv)
# Out:
# Bui Quang Chung 25021670
